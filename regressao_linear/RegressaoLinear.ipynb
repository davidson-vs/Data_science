# %% [markdown]
# <h1 style='color: green; font-size: 36px; font-weight: bold;'>Data Science - Regressão Linear</h1>

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Conhecendo o Dataset</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## Importando bibliotecas
#
# https://matplotlib.org/
#
# https://pandas.pydata.org/
#
# http://www.numpy.org/

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## Bibliotecas opcionais
#
# https://docs.python.org/3/library/warnings.html

# %% [markdown]
# ## O Dataset e o Projeto
# <hr>
#
# ### Fonte: https://www.kaggle.com/dongeorge/beer-consumption-sao-paulo
#
# ### Descrição:
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'>A cerveja é uma das bebidas mais democráticas e consumidas no mundo. Não sem razão, é perfeito para quase todas as situações, desde o happy hour até grandes festas de casamento.</p>
#
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'>O objetivo deste treinamento será estimar um modelo de <b>Machine Learning</b> utilizando a técnica de <b>Regressão Linear</b> para demonstrar os impactos das variáveis disponibilizadas neste dataset sobre o consumo de cerveja (Y). No final do projeto teremos um modelo de previsão para o consumo médio de cerveja segundo os inputs de um conjunto de variáveis (X's).</p>
#
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'>Os dados (amostra) foram coletados em São Paulo - Brasil, em uma área universitária, onde existem algumas festas com grupos de alunos de 18 a 28 anos de idade (média).</p>
#
# ### Dados:
# <ul style='font-size: 18px; line-height: 2; text-align: justify;'>
#     <li><b>data</b> - Data</li>
#     <li><b>temp_media</b> - Temperatura Média (°C)</li>
#     <li><b>temp_min</b> - Temperatura Mínima (°C)</li>
#     <li><b>temp_max</b> - Temperatura Máxima (°C)</li>
#     <li><b>chuva</b> - Precipitação (mm)</li>
#     <li><b>fds</b> - Final de Semana (1 = Sim; 0 = Não)</li>
#     <li><b>consumo</b> - Consumo de Cerveja (litros)</li>
# </ul>

# %% [markdown]
# ## Leitura dos dados

# %%
dados =  pd.read_csv("../data/Consumo_cerveja.csv", sep= ";")

# %% [markdown]
# ## Visualizar os dados

# %%
dados.head()
# Out:
#          data  temp_media  temp_min  temp_max  chuva  fds  consumo
# 0  01/01/2015       27.30      23.9      32.5    0.0    0    25461
# 1  02/01/2015       27.02      24.5      33.5    0.0    0    28972
# 2  03/01/2015       24.82      22.4      29.9    0.0    1    30814
# 3  04/01/2015       23.98      21.5      28.6    1.2    1    29799
# 4  05/01/2015       23.82      21.0      28.3    0.0    0    28900

# %% [markdown]
# ## Verificando o tamanho do dataset

# %%
dados.shape[0]
# Out:
# 365

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Análises Preliminares</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## Estatísticas descritivas

# %%
dados.describe()
# Out:
#        temp_media    temp_min    temp_max       chuva         fds  \
# count  365.000000  365.000000  365.000000  365.000000  365.000000
# mean    21.226356   17.461370   26.611507    5.196712    0.284932
# std      3.180108    2.826185    4.317366   12.417844    0.452001
# min     12.900000   10.600000   14.500000    0.000000    0.000000
# 25%     19.020000   15.300000   23.800000    0.000000    0.000000
# 50%     21.380000   17.900000   26.900000    0.000000    0.000000
# 75%     23.280000   19.600000   29.400000    3.200000    1.000000
# max     28.860000   24.500000   36.500000   94.800000    1.000000
#
#             consumo
# count    365.000000
# mean   25401.367123
# std     4399.142703
# min    14343.000000
# 25%    22008.000000
# 50%    24867.000000
# 75%    28631.000000
# max    37937.000000

# %% [markdown]
# ## Matriz de correlação
#
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'>O <b>coeficiente de correlação</b> é uma medida de associação linear entre duas variáveis e situa-se entre <b>-1</b> e <b>+1</b> sendo que <b>-1</b> indica associação negativa perfeita e <b>+1</b> indica associação positiva perfeita.</p>

# %%
dados.corr().round(4)
# Out:
#             temp_media  temp_min  temp_max   chuva     fds  consumo
# temp_media      1.0000    0.8628    0.9225  0.0244 -0.0508   0.5746
# temp_min        0.8628    1.0000    0.6729  0.0986 -0.0595   0.3925
# temp_max        0.9225    0.6729    1.0000 -0.0493 -0.0403   0.6427
# chuva           0.0244    0.0986   -0.0493  1.0000  0.0016  -0.1938
# fds            -0.0508   -0.0595   -0.0403  0.0016  1.0000   0.5060
# consumo         0.5746    0.3925    0.6427 -0.1938  0.5060   1.0000

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Comportamento da Variável Dependente (Y)</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# # Análises gráficas

# %% [markdown]
# ## Plotando a variável *dependente* (y)
# https://pandas.pydata.org/pandas-docs/stable/visualization.html

# %%
figure, ax = plt.subplots(figsize = (20, 6))
ax.set_title("Consumo de Cerveja ", fontsize = (20))
ax.set_ylabel("Litros consumidos", fontsize = (16))
ax.set_xlabel("Dias do ano", fontsize = (16))
ax = dados.consumo.plot()

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Box Plot</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# <img width='700px' src='../data/img/Box-Plot.png'>

# %% [markdown]
# ## Importando biblioteca seaborn
# https://seaborn.pydata.org/
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'>O Seaborn é uma biblioteca Python de visualização de dados baseada no matplotlib. Ela fornece uma interface de alto nível para desenhar gráficos estatísticos.</p>

# %%
import seaborn as sns

# %% [markdown]
# ## Box plot da variável *dependente* (y)

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.boxplot.html?highlight=boxplot#seaborn.boxplot

# %%
ax = sns.boxplot(data= dados['consumo'], width= 0.3)
ax.figure.set_size_inches(12,6)
ax.set_title("Consumo de cerveja", fontsize = 20)
ax.set_ylabel("Litros")
ax
# Out:
# <AxesSubplot:title={'center':'Consumo de cerveja'}, ylabel='Litros'>

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Box Plot com Duas Variáveis</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## Investigando a variável *dependente* (y) segundo determinada característica

# %%
ax = sns.boxplot( data = dados, x = "fds", y = "consumo", width= 0.3)
ax.figure.set_size_inches(12,7)
ax.set_title("Consumo de cerveja", fontsize = 20)
ax.set_ylabel("Litros Consumidos", fontsize = 16)
ax.set_xlabel("Finais de semana", fontsize = 16)
ax
# Out:
# <AxesSubplot:title={'center':'Consumo de cerveja'}, xlabel='Finais de semana', ylabel='Litros Consumidos'>

# %% [markdown]
# ## Configurações de estilo e cor da biblioteca *seaborn*
#
# ### Controle de estilo
#
# > ####  API
# > https://seaborn.pydata.org/api.html#style-api
#
# > #### Tutorial
# > https://seaborn.pydata.org/tutorial/aesthetics.html#aesthetics-tutorial
#
# ### Paleta de cores
#
# > #### API
# > https://seaborn.pydata.org/api.html#palette-api
#
# > #### Tutorial
# > https://seaborn.pydata.org/tutorial/color_palettes.html#palette-tutorial

# %%
sns.set_palette("")
sns.set_style()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\palettes.py:206, in color_palette(palette, n_colors, desat, as_cmap)
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/palettes.py?line=203'>204</a> try:
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/palettes.py?line=204'>205</a>     # Perhaps a named matplotlib colormap?
# --> <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/palettes.py?line=205'>206</a>     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/palettes.py?line=206'>207</a> except ValueError:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\palettes.py:443, in mpl_palette(name, n_colors, as_cmap)
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/palettes.py?line=441'>442</a> else:
# --> <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/palettes.py?line=442'>443</a>     cmap = mpl.cm.get_cmap(name)
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/palettes.py?line=444'>445</a> if name in MPL_QUAL_PALS:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\cm.py:286, in get_cmap(name, lut)
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/cm.py?line=284'>285</a>     return name
# --> <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/cm.py?line=285'>286</a> _api.check_in_list(sorted(_cmap_registry), name=name)
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/cm.py?line=286'>287</a> if lut is None:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\_api\__init__.py:129, in check_in_list(_values, _print_supported_values, **kwargs)
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/_api/__init__.py?line=127'>128</a>     msg += f"; supported values are {', '.join(map(repr, values))}"
# --> <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/matplotlib/_api/__init__.py?line=128'>129</a> raise ValueError(msg)
#
# ValueError: '' is not a valid value for name; supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# c:\xampp\htdocs\aulas.phyton\data_scienci\Data_scienci\regressao_linear\RegressaoLinear.ipynb Cell 34' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/xampp/htdocs/aulas.phyton/data_scienci/Data_scienci/regressao_linear/RegressaoLinear.ipynb#ch0000033?line=0'>1</a> sns.set_palette("")
#       <a href='vscode-notebook-cell:/c%3A/xampp/htdocs/aulas.phyton/data_scienci/Data_scienci/regressao_linear/RegressaoLinear.ipynb#ch0000033?line=1'>2</a> sns.set_style()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\rcmod.py:542, in set_palette(palette, n_colors, desat, color_codes)
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/rcmod.py?line=509'>510</a> def set_palette(palette, n_colors=None, desat=None, color_codes=False):
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/rcmod.py?line=510'>511</a>     """Set the matplotlib color cycle using a seaborn palette.
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/rcmod.py?line=511'>512</a>
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/rcmod.py?line=512'>513</a>     Parameters
#    (...)
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/rcmod.py?line=539'>540</a>
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/rcmod.py?line=540'>541</a>     """
# --> <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/rcmod.py?line=541'>542</a>     colors = palettes.color_palette(palette, n_colors, desat)
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/rcmod.py?line=542'>543</a>     cyl = cycler('color', colors)
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/rcmod.py?line=543'>544</a>     mpl.rcParams['axes.prop_cycle'] = cyl
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\palettes.py:208, in color_palette(palette, n_colors, desat, as_cmap)
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/palettes.py?line=205'>206</a>             palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/palettes.py?line=206'>207</a>         except ValueError:
# --> <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/palettes.py?line=207'>208</a>             raise ValueError("%s is not a valid palette name" % palette)
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/palettes.py?line=209'>210</a> if desat is not None:
#     <a href='file:///c%3A/Users/dafs/AppData/Local/Programs/Python/Python39/lib/site-packages/seaborn/palettes.py?line=210'>211</a>     palette = [desaturate(c, desat) for c in palette]
#
# ValueError:  is not a valid palette name

# %%
#verificando os dias que não são fds mas estão como outliers na pesquisa
q1 = dados.groupby("fds")['consumo'].quantile(0.25)[0]
q3 = dados.groupby("fds")['consumo'].quantile(0.75)[0]
print(q1, q3)
q2 = q3 - q1
lim_superior = q3 + (1.5*q2)

dados.query(f"consumo > {lim_superior} and fds == 0 ")
# Out:
# 21327.0 26362.0
#            data  temp_media  temp_min  temp_max  chuva  fds  consumo
# 19   20/01/2015       27.68      23.3      35.6    0.6    0    35127
# 259  17/09/2015       27.26      20.4      33.0    0.0    0    33930
# 287  15/10/2015       28.12      18.9      35.8    0.0    0    35861

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Distribuição de Frequências</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## Distribuição de frequências da variável *dependente* (y)

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.distplot.html?highlight=distplot#seaborn.distplot

# %%
ax =  sns.distplot(dados.consumo )
ax.figure.set_size_inches(12,7)
ax.set_title("Frequencia Consumo de cerveja", fontsize = 20)
ax.set_ylabel("Frequencia", fontsize = 16)
ax.set_xlabel("Litros", fontsize = 16)
ax
# Out:
# C:\Users\dafs\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Frequencia Consumo de cerveja'}, xlabel='Litros', ylabel='Frequencia'>

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Variável Dependente X Variáveis Explicativas (pairplot)</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## Gráficos de dispersão entre as variáveis do dataset

# %% [markdown]
# ## seaborn.pairplot
#
# https://seaborn.pydata.org/generated/seaborn.pairplot.html?highlight=pairplot#seaborn.pairplot
#
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'>Plota o relacionamento entre pares de variáveis em um dataset.</p>

# %%
ax = sns.pairplot(data= dados)
ax

# %% [markdown]
# ## Plotando o pairplot fixando somente uma variável no eixo y

# %%
ax = sns.pairplot(data = dados, y_vars= "consumo", x_vars= ['temp_media','temp_min', 'temp_max',"chuva", 'fds', 'consumo'])

# %%
ax = sns.pairplot(data = dados, y_vars= "consumo", x_vars= ['temp_media','temp_min', 'temp_max',"chuva", 'fds', 'consumo'],
kind= "reg")

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Variável Dependente X Variáveis Explicativas (jointplot)</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## seaborn.jointplot
#
# https://seaborn.pydata.org/generated/seaborn.jointplot.html?highlight=jointplot#seaborn.jointplot
#
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'>Plota o relacionamento entre duas variáveis e suas respectivas distribuições de frequência.</p>

# %%
ax = sns.jointplot(data=dados,  y =  'consumo', x= 'temp_media')

# %% [markdown]
# ## Plotando um jointplot com a reta de regressão estimada

# %%
ax = sns.jointplot(data= dados, x = 'temp_media', y = 'consumo', kind= 'reg')

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Variável Dependente X Variáveis Explicativas (lmplot)</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## seaborn.lmplot
#
# https://seaborn.pydata.org/generated/seaborn.lmplot.html?highlight=lmplot#seaborn.lmplot
#
# <p style='font-size: 18px; line-height: 2; margin: 10px 50px; text-align: justify;'>Plota a reta de regressão entre duas variáveis juntamente com a dispersão entre elas.</p>

# %%
ax = sns.lmplot(x = "temp_max", y="consumo", data= dados)

# %% [markdown]
# ## Plotando um lmplot utilizando uma terceira variável na análise (tipo I)

# %%
ax = sns.lmplot(x = "temp_media", y = "consumo", data= dados, hue= 'fds', markers=['o', '*'])

# %% [markdown]
# ## Plotando um lmplot utilizando uma terceira variável na análise (tipo II)

# %%
ax = sns.lmplot(x = "temp_media", y = "consumo", data= dados, col= 'fds')

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Estimando um Modelo de Regressão Linear para o Consumo</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# # Regresão Linear
# <hr>
#
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>A análise de regressão diz respeito ao estudo da dependência de uma variável (a variável <b>dependente</b>) em relação a uma ou mais variáveis, as variáveis explanatórias, visando estimar e/ou prever o valor médio da primeira em termos dos valores conhecidos ou fixados das segundas.</p>
#
#
# ## scikit-learn (https://scikit-learn.org/stable/)
#
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>O *scikit-learn* é um módulo Python especializado em soluções para *machine learning*.</p>

# %% [markdown]
# ## Importando o *train_test_split* da biblioteca *scikit-learn*
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Criando uma Series (pandas) para armazenar o Consumo de Cerveja (y)

# %%
y = dados['consumo']

# %% [markdown]
# ## Criando um DataFrame (pandas) para armazenar as variáveis explicativas (X)

# %%
x = dados[["temp_max", "chuva", 'fds']]

# %% [markdown]
# ## Criando os datasets de treino e de teste

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state= 2811)

# %% [markdown]
# ## Verificando os tamanhos dos arquivos gerados pela função *train_test_split*

# %%
x_train.shape
# Out:
# (255, 3)

# %%
x_test.shape
# Out:
# (110, 3)

# %% [markdown]
# <img width='600px' src='../data/img/reg_01.jpg'>

# %% [markdown]
# ## Importando *LinearRegression* e *metrics* da biblioteca *scikit-learn*
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html
#
# https://scikit-learn.org/stable/modules/classes.html#regression-metrics

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# ## Instanciando a classe *LinearRegression()*

# %%
modelo = LinearRegression()

# %% [markdown]
# ## Utilizando o método *fit()* do objeto "modelo" para estimar nosso modelo linear utilizando os dados de TREINO (y_train e X_train)
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression.fit

# %%
modelo.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Obtendo o coeficiente de determinação (R²) do modelo estimado com os dados de TREINO
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression.score
#
# ### Coeficiente de Determinação - R²
#
# O coeficiente de determinação (R²) é uma medida resumida que diz quanto a linha de regressão ajusta-se aos dados. É um valor entra 0 e 1.
#
# $$R^2(y, \hat{y}) = 1 - \frac {\sum_{i=0}^{n-1}(y_i-\hat{y}_i)^2}{\sum_{i=0}^{n-1}(y_i-\bar{y}_i)^2}$$

# %%
print(f"R² = {modelo.score(x_train, y_train).round(2)}")
# Out:
# R² = 0.73

# %% [markdown]
# ## Gerando previsões para os dados de TESTE (X_test) utilizando o método *predict()* do objeto "modelo"
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression.predict

# %%
y_previsto = modelo.predict(x_test)

# %% [markdown]
# ## Obtendo o coeficiente de determinação (R²) para as previsões do nosso modelo
#
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html#sklearn.metrics.r2_score

# %%
print(f"R² = {metrics.r2_score(y_test, y_previsto).round(2)}")
# Out:
# R² = 0.69

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Obtendo Previsões Pontuais</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## Dados de entrada

# %%
entrada = x_train[0:1]
entrada
# Out:
#      temp_max  chuva  fds
# 195      27.6    0.0    0

# %% [markdown]
# ## Gerando previsão pontual

# %%
modelo.predict(entrada)[0]
# Out:
# 24850.710887275698

# %% [markdown]
# ## Criando um simulador simples

# %%
temp_max = 32.6
chuva = 0
fds = 1
entrada = [[temp_max, chuva, fds]]
print(modelo.predict(entrada)[0])
# Out:
# 33675.47802085895
# C:\Users\dafs\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Interpretação dos Coeficientes Estimados</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# <img width='600px' src='../data/img/reg_02.jpg'>

# %% [markdown]
# ## Obtendo o intercepto do modelo
#
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>O <b>intercepto</b> representa o efeito médio em $Y$ (Consumo de Cerveja) tendo todas as variáveis explicativas excluídas do modelo. De forma mais simples, o <b>intercepto</b> representa o efeito médio em $Y$ (Consumo de Cerveja) quando $X_2$ (Temperatura Máxima), $X_3$ (Chuva) e $X_4$ (Final de Semana) são iguais a zero.</p>

# %%
modelo.intercept_
# Out:
# 5951.9763393124485

# %%
type(modelo.intercept_)
# Out:
# numpy.float64

# %% [markdown]
# ## Obtendo os coeficientes de regressão
#
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>Os <b>coeficientes de regressão</b> $\beta_2$, $\beta_3$ e $\beta_4$ são conhecidos como <b>coeficientes parciais de regressão</b> ou <b>coeficientes parciais angulares</b>. Considerando o número de variáveis explicativas de nosso modelo, seu significado seria o seguinte: $\beta_2$ mede a variação no valor médio de $Y$ (Consumo de Cerveja), por unidade de variação em $X_2$ (Temperatura Máxima), mantendo-se os valores de $X_3$ (Chuva) e $X_4$ (Final de Semana) constantes. Em outras palavras, ele nos dá o efeito "direto" ou "líquido" de uma unidade de variação em $X_2$ sobre o valor médio de $Y$, excluídos os efeitos que $X_3$ e $X_4$ possam ter sobre a média de $Y$. De modo análogo podemos interpretar os demais coeficientes de regressão.</p>

# %%
modelo.coef_
# Out:
# array([ 684.73675898,  -60.7824355 , 5401.08333866])

# %%
type(modelo.coef_)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Confirmando a ordem das variáveis explicativas no DataFrame

# %%
x.columns
# Out:
# Index(['temp_max', 'chuva', 'fds'], dtype='object')

# %% [markdown]
# ## Criando uma lista com os nomes das variáveis do modelo

# %%
index = ['Intercepto', 'Temperatura Maxima', "Chuva", "Final de Semana"]

# %% [markdown]
# ## Criando um DataFrame para armazenar os coeficientes do modelo
#
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.append.html?#numpy.append

# %%
pd.DataFrame( data= np.append(modelo.intercept_, modelo.coef_), index = index, columns=["Parâmetros"])
# Out:
#                      Parâmetros
# Intercepto          5951.976339
# Temperatura Maxima   684.736759
# Chuva                -60.782435
# Final de Semana     5401.083339

# %% [markdown]
# ## Interpretação dos Coeficientes Estimados
#
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>
# <b>Intercepto</b> → Excluindo o efeito das variáveis explicativas ($X_2=X_3=X_4=0$) o efeito médio no Consumo de Cerveja seria de <b>5951,98 litros</b>.
# </p>
#
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>
# <b>Temperatura Máxima (°C)</b> → Mantendo-se os valores de $X_3$ (Chuva) e $X_4$ (Final de Semana) constantes, o acréscimo de 1°C na Temperatura Máxima gera uma variação média no Consumo de Cerveja de <b>684,74 litros</b>.
# </p>
#
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>
# <b>Chuva (mm)</b> → Mantendo-se os valores de $X_2$ (Temperatura Máxima) e $X_4$ (Final de Semana) constantes, o acréscimo de 1mm de Chuva gera uma variação média no Consumo de Cerveja de <b>-60,78 litros</b>.
# </p>
#
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>
# <b>Final de Semana (Sim/Não)</b> → Mantendo-se os valores de $X_2$ (Temperatura Máxima) e $X_3$ (Chuva) constantes, o fato de o dia ser classificado como Final de Semana gera uma variação média no Consumo de Cerveja de <b>5401,08 litros</b>.
# </p>

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Análises Gráficas das Previsões do Modelo</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## Gerando as previsões do modelo para os dados de TREINO

# %%
prev_y_treino = modelo.predict(x_train)

# %% [markdown]
# ## Gráfico de dispersão entre valor estimado e valor real
#
# https://seaborn.pydata.org/generated/seaborn.scatterplot.html

# %%
sns.scatterplot(x = prev_y_treino, y = y_train)
# Out:
# <AxesSubplot:ylabel='consumo'>

# %% [markdown]
# ## Obtendo os resíduos

# %%
residuo = y_train - prev_y_treino

# %% [markdown]
# ## Gráfico de dispersão entre valor estimado e resíduos
#
# Método informal de verificação da hipótese de variância constante dos resíduos (homocedasticidade)

# %%
sns.scatterplot(x = prev_y_treino, y = residuo)
# Out:
# <AxesSubplot:ylabel='consumo'>

# %% [markdown]
# ## Utilizando os resíduos ao quadrado

# %% [markdown]
# <img width='800px' src='../data/img/var_u.jpg'>
# Fonte: Econometria Básica - 5ª edição - Gujarati e Porter

# %%
sns.scatterplot(x = prev_y_treino, y = residuo**2)
# Out:
# <AxesSubplot:ylabel='consumo'>

# %% [markdown]
# ## Plotando a distribuição de frequências dos resíduos

# %%
sns.distplot(residuo)
# Out:
# C:\Users\dafs\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='consumo', ylabel='Density'>

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Comparando Modelos</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## Estimando um novo modelo com a substituição da variável explicativa Temperatura Máxima pela Temperatuda Média

# %% [markdown]
# ## Criando os datasets de treino e de teste

# %% [markdown]
# ## Instanciando a classe *LinearRegression()*

# %% [markdown]
# ## Utilizando o método *fit()* do objeto "modelo_2" para estimar nosso modelo linear utilizando os dados de TREINO (y2_train e X2_train)

# %% [markdown]
# ## Obtendo o coeficiente de determinação (R²) do novo modelo estimado e comparando com o resultado do modelo anterior

# %% [markdown]
# ## Gerando previsões para os dados de TESTE (X_test e X2_test) utilizando o método *predict()* dos objetos "modelo" e "modelo_2"

# %% [markdown]
# ## Obtendo o coeficiente de determinação (R²) para as previsões dos dois modelos

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Outras Métricas de Regressão</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## Métricas da regressão
# <hr>
#
# fonte: https://scikit-learn.org/stable/modules/model_evaluation.html#regression-metrics
#
# Algumas estatísticas obtidas do modelo de regressão são muito úteis como critério de comparação entre modelos estimados e de seleção do melhor modelo, as principais métricas de regressão que o scikit-learn disponibiliza para modelos lineares são as seguintes:
#
# ### Erro Quadrático Médio
#
# Média dos quadrados dos erros. Ajustes melhores apresentam $EQM$ mais baixo.
#
# $$EQM(y, \hat{y}) = \frac 1n\sum_{i=0}^{n-1}(y_i-\hat{y}_i)^2$$
#
# ### Raíz do Erro Quadrático Médio
#
# Raíz quadrada da média dos quadrados dos erros. Ajustes melhores apresentam $\sqrt{EQM}$ mais baixo.
#
# $$\sqrt{EQM(y, \hat{y})} = \sqrt{\frac 1n\sum_{i=0}^{n-1}(y_i-\hat{y}_i)^2}$$

# %% [markdown]
# ## Obtendo métricas para o modelo com Temperatura Média

# %% [markdown]
# ## Obtendo métricas para o modelo com Temperatura Máxima

# %% [markdown]
# # <font color='red' style='font-size: 30px;'>Salvando e Carregando o Modelo Estimado</font>
# <hr style='border: 2px solid red;'>

# %% [markdown]
# ## Dados de entrada

# %% [markdown]
# ## Gerando previsão pontual

# %% [markdown]
# ## Criando um simulador simples

# %% [markdown]
# ## Salvando o modelo estimado

# %% [markdown]
# ## pickle (https://docs.python.org/3/library/pickle.html)
#
# <p style='font-size: 20px; line-height: 2; margin: 10px 50px; text-align: justify;'>O módulo <b>pickle</b> implementa protocolos binários para serializar e desserializar a estrutura de um objeto Python.</p>

# %% [markdown]
# ### Em um novo notebook/projeto Python
#
# <h4 style='color: blue; font-weight: normal'>In [1]:</h4>
#
# ```sh
# import pickle
#
# modelo = open('modelo_consumo_cerveja','rb')
# lm_new = pickle.load(modelo)
# modelo.close()
#
# temp_max = 30.5
# chuva = 12.2
# fds = 0
# entrada = [[temp_max, chuva, fds]]
# print('{0:.2f} litros'.format(lm_new.predict(entrada)[0]))
# ```
#
# <h4 style='color: red; font-weight: normal'>Out [1]:</h4>
#
# ```
# 26094.90 litros
# ```
